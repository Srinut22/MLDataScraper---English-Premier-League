# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
HTML_markup = (requests.get("https://fbref.com/en/squads/361ca564/Tottenham-Hotspur-Stats")).text
parsed_code = BeautifulSoup(HTML_markup, 'html.parser')

# %%
parsed_code
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" data-root="/home/fb/deploy/www/base" data-version="klecko-" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport">
# <link href="https://cdn.ssref.net/req/202309261" rel="dns-prefetch"/>
# <!-- Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->
# <script async="true" type="text/javascript">
#     (function() {
# 	var host = window.location.hostname;
# 	var element = document.createElement('script');
# 	var firstScript = document.getElementsByTagName('script')[0];
# 	var url = 'https://cmp.quantcast.com'
# 	    .concat('/choice/', 'XwNYEpNeFfhfr', '/', host,
# 		    '/choice.js?tag_version=V2');
# 	var uspTries = 0;
# 	var uspTriesLimit = 3;
# 	element.async = true;
# 	element.type = 'text/javascript';
# 	element.src = url;
#
# 	firstScript.parentNode.insertBefore(element, firstScript);
#
# ...

# %%
c = 0
def extract_info(parsed_code):
    date_elements = parsed_code.find_all("th", {"data-stat": "date"})
    dates = []
    
    goals_for_elements = parsed_code.find_all("td", {"data-stat": "goals_for"})
    goals_for_values = []
    
    goals_against_elements = parsed_code.find_all("td", {"data-stat": "goals_against"})
    goals_against_values = []
    
    opponent_elements = parsed_code.find_all("td", {"data-stat": "opponent"})
    opponents = []
    
    for date_element, goals_for_element, goals_against_element, opponent_element in zip(date_elements, goals_for_elements, goals_against_elements, opponent_elements):
        date = date_element.a.get_text() if date_element.a else date_element.get_text()
        goals_for = goals_for_element.get_text()
        goals_against = goals_against_element.get_text()
        opponent = opponent_element.a.get_text() if opponent_element.a else opponent_element.get_text()
        
        if date and goals_for and goals_against and opponent:
            if date != "Date":
                dates.append(date)
            goals_for_values.append(goals_for)
            goals_against_values.append(goals_against)
            opponents.append(opponent)
    
    return dates, goals_for_values, goals_against_values, opponents

# %%
years = []

for year in range(2023, 2000, -1):
    academic_year = f"{year}-{year + 1}"
    years.append(academic_year)

# Print the list of academic years
print(years)
# Out:
# ['2023-2024', '2022-2023', '2021-2022', '2020-2021', '2019-2020', '2018-2019', '2017-2018', '2016-2017', '2015-2016', '2014-2015', '2013-2014', '2012-2013', '2011-2012', '2010-2011', '2009-2010', '2008-2009', '2007-2008', '2006-2007', '2005-2006', '2004-2005', '2003-2004', '2002-2003', '2001-2002']

# %%
dates = []
goals_for = []
goals_against = []
opponents = []
for year in years:
    HTML_markup = requests.get(f"https://fbref.com/en/squads/361ca564/{year}/Tottenham-Hotspur-Stats").text
    parsed_code = BeautifulSoup(HTML_markup, 'html.parser')
    
    extracted_data = extract_info(parsed_code)
    
    dates.extend(extracted_data[0])
    goals_for.extend(extracted_data[1])
    goals_against.extend(extracted_data[2])
    opponents.extend(extracted_data[3])

# %%
print(len(goals_for))
print(len(goals_against))
print(len(opponents))
print(len(dates))
# Out:
# 1068
# 1068
# 1068
# 1045

# %%
data = [value.text for value in values]

data[3200:]
# Out:
# ['2',
#  'Everton',
#  '0',
#  '0',
#  'Manchester Utd',
#  '0',
#  '2',
#  'Chelsea',
#  '0',
#  '3',
#  'Crystal Palace',
#  '1',
#  '3',
#  'Bolton',
#  '3',
#  '1',
#  'Portsmouth',
#  '2',
#  '0',
#  'Fulham',
#  '0',
#  '1',
#  'Southampton',
#  '0',
#  '2',
#  'Charlton Ath',
#  '2',
#  '1',
#  'Manchester City',
#  '1',
#  '1',
#  'Birmingham City',
#  '1',
#  '0',
#  'Newcastle Utd',
#  '2',
#  '2',
#  'Liverpool',
#  '1',
#  '1',
#  'West Brom',
#  '0',
#  '1',
#  'Arsenal',
#  '5',
#  '1',
#  'Aston Villa',
#  '0',
#  '1',
#  'Middlesbrough',
#  '0',
#  '0',
#  'Blackburn',
#  '53',
#  '46',
#  '47',
#  '39',
#  '47',
#  '41',
#  '45',
#  '52',
#  '42',
#  '58',
#  '0',
#  '1',
#  'Birmingham City',
#  '2',
#  '1',
#  'Leeds United',
#  '0',
#  '0',
#  'Liverpool',
#  '0',
#  '3',
#  'Fulham',
#  '2',
#  '4',
#  'Chelsea',
#  '1',
#  '3',
#  'Southampton',
#  '0',
#  '0',
#  'Manchester City',
#  '3',
#  '0',
#  'Everton',
#  '2',
#  '1',
#  'Leicester City',
#  '0',
# ...

# %%
import pandas as pd

# Your existing DataFrame
data_values = ["Date", "Goals_For", "Goals_Against", "Opponents"]
dates = dates[1:]
data_dict = {
    "Date": dates,
    "Goals_For": goals_for,
    "Goals_Against": goals_against,
    "Opponents": opponents
}

# %%
finished_match_data
# Out:
#             Date Goals_For Goals_Against       Opponents
# 0           Date         2             2       Brentford
# 1     2023-08-13         2             0  Manchester Utd
# 2     2023-08-19         2             0     Bournemouth
# 3     2023-08-26     1 (3)         1 (5)          Fulham
# 4     2023-08-29         5             2         Burnley
# ...          ...       ...           ...             ...
# 1063  2002-04-01         1             2         Arsenal
# 1064  2002-04-06         1             1        West Ham
# 1065  2002-04-13         1             1          Bolton
# 1066  2002-04-20         1             0       Liverpool
# 1067  2002-04-27         1             2  Leicester City
#
# [1068 rows x 4 columns]

# %%
print(dates)
# Out:
# ['2023-08-13', '2023-08-19', '2023-08-26', '2023-08-29', '2023-09-02', '2023-09-16', '2023-09-24', '2023-09-30', '2023-10-07', '2023-10-23', '2022-08-06', '2022-08-14', '2022-08-20', '2022-08-28', '2022-08-31', '2022-09-03', '2022-09-07', '2022-09-13', '2022-09-17', '2022-10-01', '2022-10-04', '2022-10-08', '2022-10-12', '2022-10-15', '2022-10-19', '2022-10-23', '2022-10-26', '2022-10-29', '2022-11-01', '2022-11-06', '2022-11-09', '2022-11-12', '2022-12-26', '2023-01-01', '2023-01-04', '2023-01-07', '2023-01-15', '2023-01-19', '2023-01-23', '2023-01-28', '2023-02-05', '2023-02-11', '2023-02-14', '2023-02-19', '2023-02-26', '2023-03-01', '2023-03-04', '2023-03-08', '2023-03-11', '2023-03-18', '2023-04-03', '2023-04-08', '2023-04-15', '2023-04-23', '2023-04-27', '2023-04-30', '2023-05-06', '2023-05-13', '2023-05-20', '2021-08-15', '2021-08-19', '2021-08-22', '2021-08-26', '2021-08-29', '2021-09-11', '2021-09-16', '2021-09-19', '2021-09-22', '2021-09-26', '2021-09-30', '2021-10-03', '20
# ...
